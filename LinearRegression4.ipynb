# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model, metrics

housing = pd.read_csv('C:\machineLearning\LinearRegression4\housing_4.csv')

#Total no of columns and Rows 
housing.shape

#Doing so will print out the top 5 (0–4) rows.
housing.head()

housing.plot.scatter("median_income", "median_house_value")
# Out:
# <AxesSubplot:xlabel='median_income', ylabel='median_house_value'>

# %%
#The overall data will be split up into 80% as train and 20% as test.

x_train, x_test, y_train, y_test = train_test_split(housing.median_income, housing.median_house_value, test_size = 0.2)

#Linear Regression
regr = LinearRegression()

#This will shape the model using one predictor. 
#Reshape is being applied to change it from pandas to NumPy, and finally into a vector.
#(Reshape transverses it from a single dimension matrix to a vertical shape.)
regr.fit(np.array(x_train).reshape(-1,1), y_train)

preds = regr.predict(np.array(x_test).reshape(-1,1))

# %%
# Test Data - Actual Data 
y_test.head()
# Out:
# 17842    204100.0
# 5430     301900.0
# 9071      97700.0
# 4225     264300.0
# 16814    301000.0
# Name: median_house_value, dtype: float64

# %%
#Predicted Data
preds
# Out:
# array([281227.44795133, 188403.05495516, 151114.87170842, ...,
#        304178.48855721, 219300.28164721, 258915.08827305])

# %%
# This will show how far off the values are. 
residuals = preds - y_test
plt.hist(residuals)
# Out:
# (array([   3.,   33.,   94.,  204.,  549., 1441., 1632.,  167.,    3.,
#            2.]),
#  array([-432988.79407521, -356400.1873074 , -279811.58053958,
#         -203222.97377177, -126634.36700395,  -50045.76023613,
#           26542.84653168,  103131.4532995 ,  179720.06006731,
#          256308.66683513,  332897.27360294]),
#  <BarContainer object of 10 artists>)

# %%
#Lastly, we should use root mean squared error to find the error
mean_squared_error(y_test, preds) ** 0.5

plt.scatter(x_test, y_test)
plt.plot(x_test, preds, color='red')
plt.show()
